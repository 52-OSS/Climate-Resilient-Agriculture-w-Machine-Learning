# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data_df= pd.read_csv("/content/drive/My Drive/IDW Hackthn/data/seeds prediction1.csv")
data_df.head()
# Out:
#   seed type   time left   NO2  ...  water_vapor   latitude  longitude
# 0     Padma         120  4.81  ...        1.839  20.181627  82.185754
# 1      Bala         105  4.81  ...        1.839  20.181627  82.185754
# 2   Krishna         125  4.81  ...        1.839  20.181627  82.185754
# 3     Neela          90  4.81  ...        1.839  20.181627  82.185754
# 4    Vijaya         135  4.81  ...        1.839  20.181627  82.185754
#
# [5 rows x 30 columns]

# %%
from scipy import stats
import numpy as np

# %%
seeds=(data_df['seed type'].unique())
x=(len(seeds))
print(x)
for i in range(x):
  print(seeds[i])
# Out:
# 65
# Padma
# Bala
# Krishna
# Neela
# Vijaya
# Heera
# Kalinga-1
# Kalinga-3
# Shakti
# Panidhan
# Vani
# Anamika
# Indira
# Pallavi
# CR 1014
# Samalei
# Sattari
# Savitri/Ponmani
# CR 138-928
# CR Dhan 312
# CR Sugandh Dhan 908(Aromatic)
# CR Dhan 305
# CR Dhan 300
# CR Dhan 40
# Kiron
# Khitish
# Dharitri
# Shatabdi
# CR Dhan 506
# CR Dhan 801
# CR Dhan 510
# CR Dhan 511
# CR Dhan 309
# CR Dhan 201
# Saket-4
# Narendra-1
# Anjali
# Abhishek
# CR Dhan 500
# CR Dhan 303
# CR Dhan 310
# CR Sugandha Dhan 908(Aromatic)
# CR Dhan 802(Subhas)
# CR Dhan 306(IET 22084)
# Pooja
# CR 1002
# Naikichili
# CR Dhan 204
# CR Dhan 205(IET 22737)
# CR Dhan 701
# Vandana
# Anakima
# Chandrama
# Rajalaxmi(Hybrid)
# Chandan(CR Boro dhan 2)
# CR Dhan 601
# CR DHan 505
# CR Dhan 508
# Gangavati Agti(Aromatic)
# CR DHan 907(Aromatic)
# Purna
# Annada
# Sahnagidhan
# Sadabahar
# Hazaridhan

# %%
data_df.describe()
# Out:
#         time left         NO2        PM10  ...  water_vapor    latitude   longitude
# count  101.000000  101.000000  101.000000  ...   101.000000  101.000000  101.000000
# mean   128.762376    7.363663  104.799307  ...     4.586756   23.187668   81.913546
# std     23.347440    4.457368   47.805552  ...     6.084706    4.294662    5.790531
# min     68.000000    2.050000   22.840000  ...     0.506000   10.806441   69.069593
# 25%    111.000000    4.490000   78.360000  ...     1.839000   20.181627   76.376411
# 50%    125.000000    4.810000   88.840000  ...     2.232000   23.962636   82.185754
# 75%    148.000000   10.210000  110.080000  ...     3.945000   26.040868   85.600511
# max    187.000000   22.630000  197.350000  ...    19.666666   31.015760   93.162024
#
# [8 rows x 29 columns]

# %%
pd.DataFrame(data_df.isna().sum())
# Out:
#                       0
# seed type             0
#  time left            0
# NO2                   0
# PM10                  0
# PM25                  0
# CO                    0
# SO2                   0
# OZONE                 0
# AQI                   0
# pollutant             0
# concentration         0
# tempature             0
# apparent temperature  0
# dewPoint              0
# humidity              0
# pressure              0
# windspeed             0
# windGust              0
# windBeariing          0
# cloudCover            0
# uvIndex               0
# visibility            0
# grass_pollen          0
# tree_pollen           0
# weed_pollen           0
# soil temp             0
# soil most             1
# water_vapor           0
# latitude              0
# longitude             0

# %%
print(data_df.shape)
data_df.head()
# Out:
# (101, 30)
#   seed type   time left   NO2  ...  water_vapor   latitude  longitude
# 0     Padma         120  4.81  ...        1.839  20.181627  82.185754
# 1      Bala         105  4.81  ...        1.839  20.181627  82.185754
# 2   Krishna         125  4.81  ...        1.839  20.181627  82.185754
# 3     Neela          90  4.81  ...        1.839  20.181627  82.185754
# 4    Vijaya         135  4.81  ...        1.839  20.181627  82.185754
#
# [5 rows x 30 columns]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
for i in range(len(seeds)):
  data_df=data_df.replace(seeds[i], i)
data_df.head()
grp = data_df

# %%
request = int(input("Enter the number of seeds required"))
# Out:
# Enter the number of seeds required5

# %%
print("TOP ",request,"SEEDS SUTABLE FOR YOUR LOCATION")
for k in range(request):
  data_df = data_df[data_df['seed type']!=loc]
  data_df = data_df.dropna()
  data_df.dtypes
  X = data_df.drop(columns=['seed type'],axis=1).values
  y = data_df['seed type']
  X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
  classifier = RandomForestClassifier(n_estimators = 100)
  classifier.fit(X_train,y_train)
  y_pred = classifier.predict(X_test)
  confusion_matrix(y_test,y_pred)

  data = [[140,	9.48,	182.26,	52.39,	1.12,	0.47,	12.43,	143,	2.5,	52.39,	76.36,	76.36,	37.59,	0.25,	1016.3,	5.75,	9.97,	338,	0,	4,	10,	1,	0,	16,	35.35,	21.33333397,	0.839,	27.0790754,	76.3764112]]
  df = pd.DataFrame(data, columns = ['time left',	'NO2'	,'PM10',	'PM25',	'CO',	'SO2',	'OZONE',	'AQI',	'pollutant',	'concentration',	'tempature',	'apparent temperature',	'dewPoint',	'humidity',	'pressure',	'windspeed',	'windGust'	,'windBeariing',	'cloudCover'	,'uvIndex'	,'visibility',	'grass_pollen',	'tree_pollen',	'weed_pollen',	'soil temp',	'soil most',	'water_vapor',	'latitude',	'longitude']) 
  predict_new_persons = classifier.predict(df)

  # print("location = " + str(predict_new_persons))
  loc = np.array(predict_new_persons)
  loc = loc[0]
  seed = seeds[loc]
  print(seed)
# Out:
# TOP  5 SEEDS SUTABLE FOR YOUR LOCATION
# CR Sugandha Dhan 908(Aromatic)
# CR Dhan 801
# Abhishek
# CR Dhan 310
# CR Dhan 303

# %%
grp.head()
# Out:
#    seed type   time left   NO2  ...  water_vapor   latitude  longitude
# 0          0         120  4.81  ...        1.839  20.181627  82.185754
# 1          1         105  4.81  ...        1.839  20.181627  82.185754
# 2          2         125  4.81  ...        1.839  20.181627  82.185754
# 3          3          90  4.81  ...        1.839  20.181627  82.185754
# 4          4         135  4.81  ...        1.839  20.181627  82.185754
#
# [5 rows x 30 columns]

# %%
lon = grp['longitude'].tolist()
lot = grp['latitude'].tolist()

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Scattermapbox(
    mode = "markers+lines",
    lon = lon,
    lat = lot,
    marker = {'size': 10}))

# fig.add_trace(go.Scattermapbox(
#     mode = "markers+lines",
#     lon = [-50, -60,40],
#     lat = [30, 10, -20],
#     marker = {'size': 10}))

fig.update_layout(
    margin ={'l':0,'t':0,'b':0,'r':0},
    mapbox = {
        'center': {'lon': 10, 'lat': 10},
        'style': "stamen-terrain",
        'center': {'lon': -20, 'lat': -20},
        'zoom': 1})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5a5ab74a-90cc-4a38-ad0a-209ba7622b8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5a5ab74a-90cc-4a38-ad0a-209ba7622b8a")) {
#                     Plotly.newPlot(
#                         '5a5ab74a-90cc-4a38-ad0a-209ba7622b8a',
# ...
